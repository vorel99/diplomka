# %% [markdown]
# ---
# title: Road accidents
# date: now
# author: Jan Cap
# ---

# %%
# load municipality and filter
from geoscore_de.data_flow.features.municipality import MunicipalityFeature

muni_df = MunicipalityFeature("../../data/raw/municipalities_2022.csv").load()

# %% [markdown]
# ## Road Accident Exploration
#
# Explore road accident data and their distribution across municipalities.

# %%
import pandas as pd


def load_data(path="../../data/raw/features/46241-01-04-5-road-accidents.csv"):
    accident_columns = [
        "accident_total",
        "injury_accidents",
        "property_damage_accidents",
        "fatalities",
        "injured",
    ]

    df = pd.read_csv(
        path,
        delimiter=";",
        na_values=["-"],
        skiprows=7,
        skipfooter=4,
        engine="python",
        header=None,
        names=["MU_ID", "MU_name"] + accident_columns,
    )
    # add AGS column by right-padding MU_ID with zeros to 8 characters (adds trailing zeros if necessary)
    df["AGS"] = df["MU_ID"].str.ljust(8, "0")

    return df

# %%
raw_df = load_data()
print(f"Raw data shape: {raw_df.shape}")
raw_df.head()

# %% [markdown]
# Data contain 5 columns of interest:
# - accidents (total): Total number of road accidents in the municipality.
# - accidents with injuries: Number of road accidents that resulted in injuries.
# - accidents with property damage: Number of road accidents that resulted in property damage only.
# - fatalities: Number of fatalities resulting from road accidents.
# - injured: Number of people injured in road accidents.

# %%
merged_df = muni_df.merge(raw_df, on="AGS", how="left", indicator=True)

# %%
merged_df["_merge"].value_counts()

# %% [markdown]
# All municipalities from the municipality dataset are present in the road accident dataset. Road accident dataset contains records also for higher administrative units (districts, regions) and for the whole country, but these records are not included in the analysis.

# %%
import plotnine as gg

# create hist of total accidents
(
    gg.ggplot(merged_df, gg.aes(x="accident_total"))
    + gg.geom_histogram(bins=30)
    + gg.labs(title="Distribution of Total Accidents", x="Total Accidents", y="Count")
    + gg.scale_y_log10()
)

# %% [markdown]
# There are different sizes of municipalities in Germany, we should calculat something like accidents per capita.

# %%
# define accident columns to weight
accident_columns = [
    "accident_total",
    "injury_accidents",
    "property_damage_accidents",
    "fatalities",
    "injured",
]

# weight all accident columns by Persons (per capita)
for col in accident_columns:
    merged_df[f"{col}_per_capita"] = merged_df[col] / merged_df["Persons"]

merged_df

# %%
import plotnine as gg


def get_dist_plot(df, col):
    return (
        gg.ggplot(df, gg.aes(x=col))
        + gg.geom_histogram(bins=40)
        + gg.labs(title=f"Distribution of {col}", x=col, y="Count")
    )

# %%
for col in accident_columns:
    display(get_dist_plot(merged_df, f"{col}_per_capita"))

# %% [markdown]
# Accidents per capita are highly skewed, with many municipalities having low values and a few having very high values. Highest values are from small cities where even small number of accidents can lead to high per capita rates. Lets look at the data in x log scale to see the distribution better.

# %%
import plotnine as gg

hist_df = merged_df[["accident_total_per_capita"]].dropna().copy()
hist_df["accident_total_per_1000"] = hist_df["accident_total_per_capita"] * 1000

(
    gg.ggplot(hist_df, gg.aes(x="accident_total_per_1000"))
    + gg.geom_histogram(bins=50)
    + gg.scale_x_log10()
    + gg.labs(
        title="Total Accidents per 1000 People (log x-scale)",
        x="Total accidents per 1000 people (log scale)",
        y="Count of municipalities",
    )
)

# %% [markdown]
# On log scale x axis it look similar to normal distribution. Lets experiment with binning the data to bins of same height and see how it looks.

# %%
merged_df["binned_accidents_per_1000"] = pd.qcut(merged_df["accident_total_per_capita"] * 1000, q=10)

# %%
merged_df["binned_accidents_per_1000"].value_counts().sort_index()

# %% [markdown]
# ## Graphs for thesis

# %%
from geoscore_de.data_flow.features import RoadAccidentsFeature

road_df = RoadAccidentsFeature(
    "../../data/raw/features/46241-01-04-5-road-accidents.csv",
    tform_data_path="../../data/tform/features/road_accidents.csv",
    municipality_data_path="../../data/raw/municipalities_2022.csv",
).load_transform()
road_df = road_df.merge(muni_df, on="AGS", how="right")
road_df["accident_total_per_1000"] = road_df["accident_total"] * 1000
road_df

# %%
from geoscore_de.data_flow.geo import load_geo_data

geojson = load_geo_data("../../data/georef-germany-gemeinde.csv")

# %%
road_df.sort_values("accident_total_per_1000", ascending=False).head(5)[
    ["AGS", "Municipality", "Persons", "accident_total_per_1000"]
]

# %%
import plotnine as gg

road_df_1000 = road_df[road_df["Persons"] >= 1000].copy()
hist_df = road_df_1000[["accident_total"]].dropna().copy()
hist_df["accident_total_per_1000"] = hist_df["accident_total"] * 1000

(
    gg.ggplot(hist_df, gg.aes(x="accident_total_per_1000"))
    + gg.geom_histogram(bins=50)
    + gg.scale_x_log10()
    + gg.labs(
        title="Total Accidents per 1000 People (log x-scale) 1000+ Municipalities",
        x="Total accidents per 1000 people (log scale)",
        y="Count of municipalities",
    )
)

# %%
import matplotlib.pyplot as plt

# Join transformed road-accident data to municipality geometry.
road_map = geojson.merge(road_df[["AGS", "accident_total"]], on="AGS", how="left")

# The transformed value is per capita; convert to per 1000 people for readability.
road_map["accident_total_per_1000"] = road_map["accident_total"] * 1000

fig, ax = plt.subplots(figsize=(12, 8))
road_map.plot(
    ax=ax,
    column="accident_total_per_1000",
    cmap="YlOrRd",
    legend=True,
    legend_kwds={"label": "Total accidents per 1000 people"},
    vmax=30,
    # missing_kwds={"color": "gray"},
)
ax.set_title("Road Accidents Total per 1000 People", fontsize=13)
# ax.set_axis_off()
plt.show()

# %%
import matplotlib.pyplot as plt

# Join transformed road-accident data to municipality geometry.
road_map = geojson.merge(road_df[["AGS", "accident_total", "Persons"]], on="AGS", how="left")

# The transformed value is per capita; convert to per 1000 people for readability.
road_map["accident_total_per_1000"] = road_map["accident_total"] * 1000

fig, ax = plt.subplots(figsize=(12, 8))
road_map[road_map["Persons"] >= 1000].plot(
    ax=ax,
    column="accident_total_per_1000",
    cmap="YlOrRd",
    linewidth=0.1,
    edgecolor="white",
    vmax=20,
    legend=True,
    legend_kwds={"label": "Total accidents per 1000 people"},
)
ax.set_title("Road Accidents Total per 1000 People (1000+ inhabitants)", fontsize=13)
plt.show()

# %% [markdown]
# From the plots there is high skew in the data and there is lot of noise due to small municipalities with very high per capita accident rates (even though they have low total number of accidents).
# We can try to show binned (with equal frequencies) data on the map to see if there is any spatial pattern in the data.

# %%
road_map["accident_total_per_1000_binned"] = pd.qcut(road_map["accident_total_per_1000"], q=10, labels=False)

fig, ax = plt.subplots(figsize=(12, 8))
road_map.plot(
    ax=ax,
    column="accident_total_per_1000_binned",
    cmap="YlOrRd",
    linewidth=0.1,
    edgecolor="white",
    # vmax=30,
    legend=True,
    legend_kwds={"label": "Total accidents binned (10 quantiles)"},
    missing_kwds={"color": "gray"},
)
ax.set_title("Road Accidents Total per 1000 People (Binned)", fontsize=13)
plt.show()

# %% [markdown]
# We don't see any pattern in the binned data, but it smooths out the noise from small municipalities.
