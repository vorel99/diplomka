# %% [markdown]
# ## Election system of Germany - 2025 Federal Election
#
# Germans elect their members of parliament with two votes. The first vote is for a direct candidate, who is required to receive a plurality vote in their electoral district. The second vote is used to elect a party list in each state as established by its respective party caucus. The Bundestag comprises, then, the seats representing each electoral district on the first vote and the seats allocated to maintain proportionality based on the second vote. Common practice is that direct candidates are also placed on the electoral lists at higher rankings as a fall-back in case they do not win their districts.
#
# ### First vote
# The first vote allows the elector to vote for a direct candidate of their constituency, who applies for a direct mandate in the Bundestag (see illustration above, no. 2). A plurality voting system is used, which means that the candidate who receives more votes than any other candidate gets the mandate. If the vote results in a tie, the lot drawn by the leader of the regional election is decisive. In this case, the votes for the other candidates are invalid. The primary function of the first vote is to personalize the election. As there are 299 constituencies (regions) at the moment, the same number of mandates in the Bundestag are distributed to the elected candidates in each district. However, the first vote does not determine the power of the parties in the Bundestag. For each direct mandate in a Bundesland the party always receives one mandate fewer from the second vote.
#
# ### Second vote
# For the distribution of seats in the German Bundestag, the second vote is more important than the first vote. This second vote allows the elector to vote for a party whose candidates are put together on the regional electoral list. Based on the proportion of second votes, the 598 mandates are distributed to the parties which have achieved at least 5 percent of valid second votes.

# %% [markdown]
# This will download folder containing two csv files and four pdf files.
# First csv file `btw25_wbz_ergebnisse.csv` contains results of the election by voting districts.
# Second csv file `btw25_wbz_leitband.csv` contains metadata about the voting districts.
#
# Contents:
# The files `btw25_wbz_ergebnisse.csv` contain data records for all approximately 90,000 electoral districts with the following information:
# • Constituency number, municipality code, municipality name, electoral district number, and district type
# • Total number of eligible voters, with and without voting card notation
# • Total number of voters and voters with voting cards
# • Total number of invalid and valid first and second votes
# • Number of first and second votes for each party.
#
# An additional file contains the following explanatory information
# (mainly on the territorial status as of December 31, 2024):
# • State names
# • Administrative district names
# • County names
# • Association municipality names
# • Municipality names for the municipality codes listed.
#
# The municipal codes used are identical to the key numbers in the official
# municipal directory.
#
# A special feature is the joint postal voting districts for several municipalities. All municipalities
# in a district that form a joint postal voting committee are assigned the same 2-digit number in the additional field EF8
# “Postal voting affiliation.” The municipality code for the joint
# postal voting districts consists of the number “9” and this 2-digit number. The 4-digit
# association municipality code for this district corresponds to the association municipality code if all municipalities belong to the same association.
#  Otherwise, it consists of the digits
# “11” and the 2-digit postal vote affiliation number.
# These special features were ignored and merged on AGS level with the rest of data.

# %% [markdown]
# Description of features:
# - Wahlkreis: Constituency number (voting district) - there are 299 constituencies in total, Each constituency votes for one direct candidate (first vote) and contributes to the proportional representation of parties (second vote).
# - Land: State
# - Regierungsbezirk: Administrative district
# - Kreis: County
# - Verbandsgemeinde: Association municipality
# - Gemeinde: Municipality id (city/town)
# - Kennziffer Briefwahlzugehörigkeit: Postal ballot code
# - Gemeindename: Municipality name (city/town)
# - Wahlbezirk: Electoral district number (within the municipality)
# - Bezirkstart: District type
#     - 0: Ballot box district
#     - 5: Postal voting district
#     - 6: Special district
#     - 8: District for eligible voters without further details
# - Wahlberechtigte (A): Total number of eligible voters
# - Wahlberechtigte ohne Sperrvermerk (A1): Total number of eligible voters without voting card notation (i.e., those who can vote in person)
# - Wahlberechtigte mit Sperrvermerk (A2): Total number of eligible voters with voting card notation (i.e., those who can only vote by mail)
# - Wahlberechtigte nach § 25 Abs. 2 BWO (A3): Total number of eligible voters according to § 25 Abs. 2 BWO (e.g., for certain special districts)
# - Wählende (B): Total number of voters
# - Wählende mit Wahlschein (B1): Total number of voters including those with voting cards
# - Any Erststimmen: First votes for each party
# - Any Zweitstimmen: Second votes for each party
# - Ungekürzte Wahlbezirksbezeichnung: Unabridged electoral district description
# - Bezeichnung des Wahlbezirkes gemäß Anlage 30 zur BWO: Electoral district description according to Annex 30 of the BWO
#
#
# The unique identifier of a voting district is a combination of `Wahlkreis` (constituency number), `Kreis` (county), and `Gemeinde` (municipality).

# %%
import matplotlib.pyplot as plt
import pandas as pd

from geoscore_de.data_flow.features.municipality import load_municipality_data

df_muni = load_municipality_data("../../data/raw/municipalities_2022.csv")

# %% [markdown]
# ## Exploratory data analysis

# %%
dtype_mappings = {
    "Land": str,
    "Regierungsbezirk": str,
    "Kreis": str,
    "Verbandsgemeinde": str,
    "Gemeinde": str,
}
df_elec = pd.read_csv(
    "../../data/raw/features/election_2025/btw25_wbz_ergebnisse.csv", sep=";", skiprows=4, dtype=dtype_mappings
)

# Add municipality codes from Land, Regierungsbezirk, Kreis, and Gemeinde columns as strings
df_elec["municipality_code"] = (
    df_elec["Land"]
    + df_elec["Regierungsbezirk"]
    + df_elec["Kreis"]
    + df_elec["Verbandsgemeinde"]
    + df_elec["Gemeinde"].str.zfill(3)
)
df_elec["AGS"] = df_elec["Land"] + df_elec["Regierungsbezirk"] + df_elec["Kreis"] + df_elec["Gemeinde"].str.zfill(3)

df_elec.head(10)

# %%
print("Number of unique municipalities in election data:", df_elec["municipality_code"].nunique())
print("Number of unique municipalities in municipality data:", df_muni["MU_ID"].nunique())

# %%
df_elec_grouped = df_elec.groupby("AGS").first().reset_index()

df_merged = df_elec_grouped.merge(df_muni, left_on="AGS", right_on="AGS", how="outer", indicator=True)

# %%
df_merged["_merge"].value_counts()

# %% [markdown]
# There is a lot of unmapped municipalities in the data. Lets first explore unmapped voting data and then unmatched municipality data. There is 596 extra records in the election data and 116 extra records in the municipality data.

# %% [markdown]
# ### Explore missing municipalities in municipality data
#
# There could be same problem as in 2021 federal election, where there were municipalities with number 9 at sixth digit of AGS code. Those records represent nature reserves, forests, etc. These records are not relevant for our analysis, and can be safely ignored. We will check if there are such records in the 2025 election data and if they can explain all missing municipalities.

# %%
df_merged[(df_merged["_merge"] == "left_only") & (df_merged["AGS"].str.slice(5, 6) == "9")][["AGS", "Gemeindename"]]

# %% [markdown]
# This filtering resolved 571 out of 596 unmatched election records, which means that only 25 records remain unmatched. Lets explore those records in more detail.

# %%
df_merged[(df_merged["_merge"] == "left_only") & (df_merged["AGS"].str.slice(5, 6) != "9")][["AGS", "Gemeindename"]]

# %% [markdown]
# Same as in 2021 election, there are city districts of Berlin and Hamburg. Election data contains records for those city districts, but municipality data does not. We will have to merge those city districts into one record for Berlin and one record for Hamburg in the election data to be able to merge it with municipality data.
#
# After ignoring those city districts, there are only 4 unmatched records left in the election data. Those record represent Obergeckler, Jahnatal, Uder and Berga-Wünschendorf.
# We will ignore those records as well, because they represent very small number of voters and resolving them would require a lot of manual work.

# %% [markdown]
# ### Explore with municipalities are missing in Election data

# %% [markdown]
# We have 116 unmatched records in the municipality data.
# In analyses of 2021 election data, we found out that some municipalities are merged in the election data. The record for merged municipality contains word *einschl.* (including) in the name of the municipality. We will check if there are such records in the 2025 election data and if they can explain all missing municipalities.

# %%
# explore voting data for einschl. records
df_elec_grouped[df_elec_grouped["Gemeindename"].str.contains("einschl.")][["AGS", "Gemeindename"]]

# %% [markdown]
# We found 93 municipalities containing word *einschl.* in the name in the election data. We will try to merge all of extra municipality records based on substring matching in the name of the municipality.

# %%
missing_names = df_merged[df_merged["_merge"] == "right_only"]["Municipality"].tolist()
einschl_names = df_elec_grouped[df_elec_grouped["Gemeindename"].str.contains("einschl.")]["Gemeindename"].tolist()

present_in_einschl = []
missing_in_einschl = []
for name in missing_names:
    if any(name in einschl_name for einschl_name in einschl_names):
        present_in_einschl.append(name)
    else:
        missing_in_einschl.append(name)
len(present_in_einschl)

# %% [markdown]
# This approach resolved 69 out of 116 unmatched municipality records. The remaining 47 unmatched municipality records are:

# %%
missing_in_einschl

# %% [markdown]
# Resolving those remaining unmatched municipality records would require a lot of manual work, and they represent very small number of voters, so we will ignore those records as well.

# %% [markdown]
# ## Graphs for thesis

# %%
from geoscore_de.data_flow.features import Election25Feature

df = Election25Feature(
    raw_data_path="../../data/raw/features/election_2025/",
    tform_data_path="../../data/tform/features/federal_election_25.csv",
    municipality_data_path="../../data/raw/municipalities_2022.csv",
).load_transform()
df.shape

# %%
df[df["AGS"].isin(["02000000", "11000000"])]

# %%
# all cols that start with Z_
z_cols = list(df.columns[df.columns.str.startswith("Z_")])
z_cols.remove("Z_invalid_votes")
z_cols.remove("Z_valid_votes")
print(f"Columns that start with Z_: {z_cols}")
e_cols = list(df.columns[df.columns.str.startswith("E_")])
e_cols.remove("E_invalid_votes")
e_cols.remove("E_valid_votes")
print(f"Columns that start with E_: {e_cols}")

# %%
party_order = ["CDU", "SPD", "AfD", "Die Linke", "GRÜNE", "CSU", "Other"]
party_colors = [
    "#5F6A6E",  # CDU
    "#C7004C",  # SPD
    "#74B9D6",  # AfD
    "#5E3A78",  # DIE LINKE
    "#0B8F4B",  # GRÜNE
    "#005082",  # CSU
    "#B7B7B7",  # Other
]

# %%
# now show it on map of germany
from geoscore_de.data_flow.geo import load_geo_data

df = df.merge(df_muni[["AGS", "Municipality"]], on="AGS", how="right")

gdf = load_geo_data("../../data/georef-germany-gemeinde.csv")
gdf_merged = gdf.merge(df, left_on="AGS", right_on="AGS", how="left")

# %%
gdf_merged["winner_1"] = gdf_merged[e_cols].idxmax(axis=1).str.replace("E_", "", regex=False)
gdf_merged.loc[(~gdf_merged["winner_1"].isin(party_order)) & (gdf_merged["winner_1"].notna()), "winner_1"] = "Other"
# winner party per municipality (based on second votes)
gdf_merged["winner_2"] = gdf_merged[z_cols].idxmax(axis=1).str.replace("Z_", "", regex=False)
gdf_merged.loc[(~gdf_merged["winner_2"].isin(party_order)) & (gdf_merged["winner_2"].notna()), "winner_2"] = "Other"

# %%
gdf_merged["winner_1"].value_counts()

# %%
gdf_merged["winner_2"].value_counts()

# %%
# Normalize winner labels in case they still contain Z_ prefix from earlier runs.
from matplotlib.colors import ListedColormap

winner_clean = gdf_merged["winner_1"].astype("string")
gdf_merged["winner_1"] = pd.Categorical(winner_clean, categories=party_order, ordered=True)

fig, ax = plt.subplots(1, 1, figsize=(12, 8))

gdf_merged.plot(
    ax=ax,
    column="winner_1",
    legend=True,
    cmap=ListedColormap(party_colors),
    legend_kwds={"loc": "upper left", "title": "Winning party"},
    missing_kwds={"color": "#FFFFFF", "label": "No data"},
)
plt.title("Winning party in 2025 federal election (first votes)")

plt.show()

# %%
import pandas as pd
from matplotlib.colors import ListedColormap

# Normalize winner labels in case they still contain Z_ prefix from earlier runs.
winner_clean = gdf_merged["winner_2"].astype("string")
gdf_merged["winner_2"] = pd.Categorical(winner_clean, categories=party_order, ordered=True)

fig, ax = plt.subplots(1, 1, figsize=(12, 8))

gdf_merged.plot(
    ax=ax,
    column="winner_2",
    legend=True,
    cmap=ListedColormap(party_colors),
    legend_kwds={"loc": "upper left", "title": "Winning party"},
    missing_kwds={"color": "#FFFFFF", "label": "No data"},
)
plt.title("Winning party in 2025 federal election (second votes)")

plt.show()

# %% [markdown]
# CDU won almost all of western Germany, while CSU won in Bavaria. CDU and CSU form one party on federal level, but they run separately in different states. AfD won basically all of eastern Germany, except for Berlin, where Die Linke won. SPD lost almost all of its territories from 2021 election, but won in some cities, such as Hamburg.

# %%
# Calculate overall voter turnout across all municipalities
gdf_merged["total_voters"].sum() / gdf_merged["eligible_voters"].sum()

# %%
# map of voter turnout in 2021 federal election (second votes)
fig, ax = plt.subplots(1, 1, figsize=(12, 8))

gdf_merged["voter_turnout"] = gdf_merged["total_voters"] / gdf_merged["eligible_voters"]
gdf_merged.plot(
    ax=ax,
    column="voter_turnout",
    cmap="YlOrRd_r",
    legend=True,
    missing_kwds={"color": "#FFFFFF", "label": "No data"},
    vmin=0,
    vmax=1,
)
plt.title("Voter turnout in 2025 federal election")

# %% [markdown]
# Voter turnout in 2025 federal election was overall 80% (about 6% higher than in 2021), but had same spatial pattern.
