# %% [markdown]
# ---
# title: Births analysis
# date: now
# author: Jan Cap
# ---

# %%
from geoscore_de.data_flow.features.municipality import MunicipalityFeature

municipalities = MunicipalityFeature("../../data/raw/municipalities_2022.csv")
municipalities = municipalities.load_transform()
municipalities

# %% [markdown]
# ## Explore birth data

# %%
from geoscore_de.data_flow.features import BirthFeature

raw_df = BirthFeature(raw_data_path="../../data/raw/features/12612-91-01-5-births.csv").load()
raw_df

# %% [markdown]
# Raw data is from the file `12612-91-01-5-births.csv`, it is valid to year 2023. it contains data for multiple regional levels (municipality, district, etc.) and contains only one feature column, which is the number of births.
# Data were weighted by the population of the municipality to get the number of births per capita.

# %%
df = BirthFeature(
    raw_data_path="../../data/raw/features/12612-91-01-5-births.csv",
    tform_data_path="../../data/tform/features/births.csv",
    municipality_data_path="../../data/raw/municipalities_2022.csv",
).load_transform()
df

# %%
df_merged = municipalities.merge(df, on="AGS", how="left", indicator=True)
df_merged["_merge"].value_counts()

# %% [markdown]
# We can see that all municipalities from the municipalities dataset are present in the birth data, but there are some additional rows in the birth data that do not have a match in the municipalities dataset. These additional rows likely correspond to higher-level administrative units (e.g., districts, states) that can be ignored for our analysis.

# %%
df_merged["births"].isna().sum()

# %% [markdown]
# There is 518 missing values in the birth data, which is not problem with data alignment, but rather a result of the fact that some municipalities do not report birth data. We can explore the municipalities with missing birth data to see if there are any patterns or common characteristics among them.

# %%
df_missing = df_merged[df_merged["births"].isna()]
df_missing

# %%
import plotnine as gg

(
    gg.ggplot(df_missing, gg.aes(x="Persons"))
    + gg.geom_histogram(bins=40)
    + gg.xlim(0, None)
    + gg.labs(x="Municipality Size", y="Count", title="Distribution of Municipality Sizes with Missing Birth Data")
)

# %% [markdown]
# We can see that most of the municipalities with missing birth data are small (under 500 inhabitants). It could mean that they do not have the resources to report birth data, or that they have very low birth rates and therefore do not report it.

# %%
(
    gg.ggplot(df_merged, gg.aes(x="births"))
    + gg.geom_histogram(bins=40)
    + gg.xlim(0, None)
    + gg.labs(
        x="Number of Births per capita", y="Count", title="Distribution of Births per capita across Municipalities"
    )
)

# %% [markdown]
# most of the municipalities have birth rates between 0 and 0.02, which means that they have between 0 and 2 births per 100 inhabitants. There are some outliers with higher birth rates, but they are not very common.

# %% [markdown]
# ## Visualization

# %%
# now show it on map of germany
from geoscore_de.data_flow.geo import load_geo_data

gdf = load_geo_data("../../data/georef-germany-gemeinde.csv")

# %%
# join data by ags
gdf_merged = gdf.merge(df_merged, on="AGS", how="outer")

# %%
import matplotlib.pyplot as plt

gdf_merged.plot(
    column="births",
    legend=True,
    cmap="YlOrRd",
    figsize=(12, 8),
    vmin=0,
    vmax=0.03,
    missing_kwds={"color": "gray"},
)
plt.title("Proportional births in German Municipalities 2023")
plt.show()

# %% [markdown]
# Looks like the former East Germany has slightly lower birth rates than the former West Germany, but there are some exceptions. It can corelate with the fact that the former East Germany has higher amount of old people, and therefore lower birth rates.
